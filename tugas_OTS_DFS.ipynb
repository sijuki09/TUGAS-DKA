# %% [markdown]
# ### soal 1

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque

# Inisialisasi graf
G = nx.Graph()

# Menambahkan edge dan bobot jarak antar kota
edges = [
    ('Arad', 'Zerind', 75),
    ('Zerind', 'Oradea', 71),
    ('Oradea', 'Sibiu', 151),
    ('Arad', 'Sibiu', 140),
    ('Arad', 'Timisoara', 118),
    ('Timisoara', 'Lugoj', 111),
    ('Lugoj', 'Mehadia', 70),
    ('Mehadia', 'Drobeta', 75),
    ('Drobeta', 'Craiova', 120),
    ('Sibiu', 'Fagaras', 99),
    ('Sibiu', 'Rimnicu Vilcea', 80),
    ('Rimnicu Vilcea', 'Pitesti', 97),
    ('Rimnicu Vilcea', 'Craiova', 146),
    ('Craiova', 'Pitesti', 138),
    ('Fagaras', 'Bucharest', 211),
    ('Pitesti', 'Bucharest', 101),
    ('Bucharest', 'Giurgiu', 90),
    ('Bucharest', 'Urziceni', 85),
    ('Urziceni', 'Hirsova', 98),
    ('Hirsova', 'Eforie', 86),
    ('Urziceni', 'Vaslui', 142),
    ('Vaslui', 'Iasi', 92),
    ('Iasi', 'Neamt', 87)
]
G.add_weighted_edges_from(edges)

# Posisi manual sesuai layout dari peta
pos = {
    'Arad': (0, 0),
    'Zerind': (-1, 1),
    'Oradea': (-2, 2),
    'Sibiu': (1, 1),
    'Timisoara': (-1, -1),
    'Lugoj': (-1, -2),
    'Mehadia': (-1, -3),
    'Drobeta': (-1, -4),
    'Craiova': (0, -4),
    'Rimnicu Vilcea': (1, -2),
    'Pitesti': (2, -3),
    'Fagaras': (2, 1),
    'Bucharest': (3, -2),
    'Giurgiu': (3, -3),
    'Urziceni': (4, -1),
    'Hirsova': (5, -1),
    'Eforie': (6, -1),
    'Vaslui': (5, 0),
    'Iasi': (6, 1),
    'Neamt': (7, 2)
}

# Gambar graf
plt.figure(figsize=(12, 8))
nx.draw(
    G, pos,
    with_labels=True,
    node_color='red',
    edge_color='black',
    node_size=1000,
    font_color='white',
    font_size=6,
    font_weight='bold',
    width=2
)

# Tambahkan label bobot di atas edge
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels=edge_labels,
    font_color='green',
    font_size=12,
    label_pos=0.6
)

plt.title("Graf Kota Romania (Dengan Bobot dan Posisi Seperti Peta)", fontsize=14)
plt.axis("off")
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
plt.show()

# Fungsi DFS
def dfs(graph, start, goal):
    visited = set()
    stack = [(start, [start])]  # (kota_sekarang, path_sampai_sini)

    while stack:
        current, path = stack.pop()
        if current == goal:
            return path

        if current not in visited:
            visited.add(current)
            for neighbor in graph.neighbors(current):
                if neighbor not in visited:
                    stack.append((neighbor, path + [neighbor]))

    return None  # Tidak ditemukan

# Panggil DFS
start_city = "Arad"
goal_city = "Bucharest"
path_result = dfs(G, start_city, goal_city)

if path_result:
    print(f"Jalur DFS dari {start_city} ke {goal_city}:")
    print(" -> ".join(path_result))
else:
    print("Jalur tidak ditemukan.")
# Out:
# Jalur DFS dari Arad ke Bucharest:
# Arad -> Timisoara -> Lugoj -> Mehadia -> Drobeta -> Craiova -> Pitesti -> Bucharest

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Inisialisasi graf
G = nx.Graph()

# Menambahkan edge dan bobot jarak antar kota
edges = [
    ('Jakarta', 'Cirebon', 327),
    ('Jakarta', 'Bandung', 270),
    ('Cirebon', 'Bandung', 120),
    ('Cirebon', 'Yogyakarta', 210),
    ('Cirebon', 'Semarang', 305),
    ('Bandung', 'Yogyakarta', 373),
    ('Semarang', 'Yogyakarta', 109),
    ('Semarang', 'Surakarta', 97),
    ('Semarang', 'Surabaya', 369),
    ('Surabaya', 'Malang', 94),
    ('Surakarta', 'Malang', 370),
    ('Surakarta', 'Yogyakarta', 60),
]
G.add_weighted_edges_from(edges)

# Posisi manual sesuai layout dari peta
pos = {
    'Jakarta': (0, 0),
    'Bandung': (1.5, -1),
    'Cirebon': (2.5, 1),
    'Yogyakarta': (4, -1),
    'Surakarta': (5, -2),
    'Semarang': (4, 1),
    'Surabaya': (7, -1),
    'Malang': (8, -2),
}

# Fungsi DFS
def dfs(graph, start, goal):
    visited = set()
    stack = [(start, [start])]

    while stack:
        current, path = stack.pop()
        if current == goal:
            return path

        if current not in visited:
            visited.add(current)

            for neighbor in graph.neighbors(current):
                if neighbor not in visited:
                    stack.append((neighbor, path + [neighbor]))
    
    return None

# Jalankan DFS
start_city = "Bandung"
goal_city = "Surakarta"
path_result = dfs(G, start_city, goal_city)

# Gambar graf
plt.figure(figsize=(12, 8))
nx.draw(
    G, pos,
    with_labels=True,
    node_color='red',
    edge_color='black',
    node_size=1000,
    font_color='white',
    font_size=8,
    font_weight='bold',
    width=2
)

# Tambahkan label bobot (weight) di atas edge
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels=edge_labels,
    font_color='green',
    font_size=12,
    label_pos=0.5,  # atur posisi label di tengah edge
    rotate=False    # label horizontal agar lebih mudah dibaca
)

# Highlight jalur hasil DFS
if path_result:
    edge_path = list(zip(path_result, path_result[1:]))
    nx.draw_networkx_edges(G, pos, edgelist=edge_path, edge_color='blue', width=4)
    print(f"Jalur DFS dari {start_city} ke {goal_city}:")
    print(" -> ".join(path_result))
else:
    print("Jalur tidak ditemukan.")

plt.title("Graf Kota", fontsize=14)
plt.axis("off")
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
plt.show()
# Out:
# Jalur DFS dari Bandung ke Surakarta:
# Bandung -> Yogyakarta -> Surakarta
